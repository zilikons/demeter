# %%
# !pip install geopandas
import geopandas as gpd

# %%
germany = gpd.read_file('../raw_data/germany.json')

# %%
germany[['NAME_3','geometry']]
# Out:
#                  NAME_3                                           geometry
# 0          Allmendingen  MULTIPOLYGON (((9.82220 48.31950, 9.80970 48.3...
# 1            Blaubeuren  MULTIPOLYGON (((9.83130 48.45610, 9.83280 48.4...
# 2             Blaustein  MULTIPOLYGON (((9.82750 48.45700, 9.82610 48.4...
# 3            Dietenheim  MULTIPOLYGON (((10.08380 48.19700, 10.08570 48...
# 4             Dornstadt  MULTIPOLYGON (((9.90640 48.43220, 9.90400 48.4...
# ...                 ...                                                ...
# 4675          Grammetal  MULTIPOLYGON (((11.26150 50.93760, 11.25890 50...
# 4676  Ilmtal-Weinstraße  MULTIPOLYGON (((11.39260 50.99050, 11.39070 50...
# 4677        Kranichfeld  MULTIPOLYGON (((11.21320 50.80440, 11.20630 50...
# 4678          Mellingen  MULTIPOLYGON (((11.49150 50.89630, 11.49600 50...
# 4679    NordkreisWeimar  MULTIPOLYGON (((11.35290 51.02160, 11.33310 51...
#
# [4680 rows x 2 columns]

# %%
germany[germany['NAME_3']=='Berlin'].plot()
# Out:
# <Axes: >

# %%
germany[germany['NAME_3']=='Hamburg'].plot()
# Out:
# <Axes: >

# %%
germany[germany['NAME_3']=='München'].plot()
# Out:
# <Axes: >

# %%
germany[germany['NAME_3']=='München'].plot()
# Out:
# <Axes: >

# %%
y = gpd.read_file('../raw_data/biodiversity_berlin.csv')

# %%
y.head()
# Out:
#        gbifID                            datasetKey  \
# 0  2832407287  8a863029-f435-446a-821e-275f4f641165
# 1  3906824794  8a863029-f435-446a-821e-275f4f641165
# 2  2836060223  8a863029-f435-446a-821e-275f4f641165
# 3  2832961073  8a863029-f435-446a-821e-275f4f641165
# 4  2839312403  8a863029-f435-446a-821e-275f4f641165
#
#                                     occurrenceID   kingdom    phylum class  \
# 0   https://observation.org/observation/81084816  Animalia  Chordata  Aves
# 1  https://observation.org/observation/253443812  Animalia  Chordata  Aves
# 2  https://observation.org/observation/114911820  Animalia  Chordata  Aves
# 3  https://observation.org/observation/138429429  Animalia  Chordata  Aves
# 4  https://observation.org/observation/104623093  Animalia  Chordata  Aves
#
#            order        family           genus                        species  \
# 0  Passeriformes  Fringillidae       Carduelis            Carduelis carduelis
# ...
